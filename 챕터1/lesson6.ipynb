# %%
def hello():
    print("hello")

hello()
# Out:
# hello

# %%
def hello(name = "홍길동"):
    print("안녕하세요, ", name, "님!")

hello("윤승환")
hello()
# Out:
# 안녕하세요,  윤승환 님!
# 안녕하세요,  홍길동 님!

# %% [markdown]
# '''
# Q3
# a,b라는 숫자를 매개변수로 가지는 add_numbers라는 함수를 만들고,
# a + b의 결과를 result라는 변수에 담아 return 하도록 해 주세요
# '''

# %%
def add_numbers(a, b):
    result = a+b
    return result

print (add_numbers(1,2))
# Out:
# 3

# %%
# 모듈(datetime) 에 있는 클래스(datetime)를 불러옴
from datetime import datetime

# 자료형 datetime today 변수 초기화
today = datetime.now()




text = today.strftime("%Y/%m/%d")
print(text)
print(datetime.now())
# Out:
# 2026/07/01
# 2026-07-01 23:44:25.636818
# Hello
