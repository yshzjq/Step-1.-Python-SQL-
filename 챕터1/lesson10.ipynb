# %%
i = 1
while i <= 5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <= 5:
    print(i)
    break
# Out:
# 1

# %%
count = 1

while True:
    print(count)

    if count == 5:
        break

    count += 1

print('while 반복문 끝')
# Out:
# 1
# 2
# 3
# 4
# 5
# while 반복문 끝

# %%
i = 0

while i<5:
    i+=1
    if i == 3 :
        continue
    print(i)

print('끝')
# Out:
# 1
# 2
# 4
# 5
# 끝
