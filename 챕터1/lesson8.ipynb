# %%
x = 10
is_big = x > 5
print(is_big)   # True
# Out:
# True

# %%
x = True

# %%
print(x)
# Out:
# True

# %%
age = 50

if age >= 19:
    print("성인입니다.")
# Out:
# 성인입니다.

# %%
print(10 == 10)
print(10 != 5)
print(3 > 10)
print(3 <= 10)
# Out:
# True
# True
# False
# True

# %%
text = "가족 관람 가능"
print("가족" in text)
print("청소년" not in text)
# Out:
# True
# True

# %%
print(True and True)
# Out:
# True

# %%
events = [
    {
            "공연/행사명": "[동작문화재단] 2025 본동어울마당 아트홀 정기 기획공연 [본?사람?잇다] 7회차",
            "이용대상": "누구나",
            "이용요금": "무료",
            "프로그램소개": "어린이들이 상상력과 창의력을 키울 수 있도록 기획된 융합형 예술 공연을 선보인다. 마술, 샌드아트, 쉐도우쇼, 레이저 퍼포먼스 등 다양한 장르가 어우러져 어린이 관객들에게 공연에 대한 몰입과 감동을 자연스럽게 선사한다."
        },
    {
            "공연/행사명": "[영등포문화재단] 2025 YDP창의예술교육센터 결과공유축제 [둥둥제]",
            "이용대상": "성인, 청소년, 어린이 ",
            "이용요금": "무료 ",
            "프로그램소개": "창터 창작공간 프로그램, 창터 X 공방협력 프로그램, 둥둥 특강 "
        },
    {
            "공연/행사명": "[성동문화재단] 크리스마스 발레 [호두까기 인형]",
            "이용대상": "구민 및 일반시민",
            "이용요금": "전석 3만원 (성동구민, 학생, 장애인, 복지카드 소지자 50% 할인)",
            "프로그램소개": "눈부신 겨울 무대와 차이콥스키의 아름다운 음악이 함께하는 크리스마스 대표 발레 ‘호두까기 인형’이 새롭게 소월아트홀을 찾아옵니다. 아름다운 선율, 화려한 군무, 깊은 서사가 어우러져 전 세계 관객에게 사랑받는 스터디셀러 공연! 사랑하는 가족과 함께 최고의 크리스마스를 소월아트홀에서 보내세요."
        },
    {
            "공연/행사명": "[서울공예박물관] 금기숙 기증특별전 [Dancing, Dreaming, Enlightening]",
            "이용대상": "누구나",
            "이용요금": "무료",
            "프로그램소개": ""
        },
    {
            "공연/행사명": "[강동문화재단] 쇼뮤지컬 [프린세스 캐치! 티니핑]",
            "이용대상": "24개월 이상 관람가",
            "이용요금": "R석 77,000원 / S석 55,000원",
            "프로그램소개": ""
        }
]

print("샘플 행사 수:", len(events))
print("키 목록:", events[0].keys())
# Out:
# 샘플 행사 수: 5
# 키 목록: dict_keys(['공연/행사명', '이용대상', '이용요금', '프로그램소개'])

# %% [markdown]
# events[4]에 대해서
# 해당 행사의 ‘이용대상’ 설명, ‘프로그램소개’ 설명을 통해 어린이/가족/유아/청소년 키워드가 들어갔는지 판별하고
# ‘이용요금’ 키를 통해 무료인지도 판별해서
# is_kid_friendly (유아 친화적인지 여부) 와 is_free(무료 여부) 객체를 만들고 Boolean 값으로 출력해보세요.

# %%
target_event = events[4]

text = target_event['이용대상'] + target_event['이용요금']


is_kid_friendly = '어린이' in text  or '가족' in text or '유아' in text or '청소년' in text

print(is_kid_friendly)

print("무료" in text)
# Out:
# False
# False

# %%
events = [
    {
            "공연/행사명": "[동작문화재단] 2025 본동어울마당 아트홀 정기 기획공연 [본?사람?잇다] 7회차",
            "이용대상": "누구나",
            "이용요금": "무료",
            "프로그램소개": "어린이들이 상상력과 창의력을 키울 수 있도록 기획된 융합형 예술 공연을 선보인다. 마술, 샌드아트, 쉐도우쇼, 레이저 퍼포먼스 등 다양한 장르가 어우러져 어린이 관객들에게 공연에 대한 몰입과 감동을 자연스럽게 선사한다."
        },
    {
            "공연/행사명": "[영등포문화재단] 2025 YDP창의예술교육센터 결과공유축제 [둥둥제]",
            "이용대상": "성인, 청소년, 어린이 ",
            "이용요금": "무료 ",
            "프로그램소개": "창터 창작공간 프로그램, 창터 X 공방협력 프로그램, 둥둥 특강 "
        },
    {
            "공연/행사명": "[성동문화재단] 크리스마스 발레 [호두까기 인형]",
            "이용대상": "구민 및 일반시민",
            "이용요금": "전석 3만원 (성동구민, 학생, 장애인, 복지카드 소지자 50% 할인)",
            "프로그램소개": "눈부신 겨울 무대와 차이콥스키의 아름다운 음악이 함께하는 크리스마스 대표 발레 ‘호두까기 인형’이 새롭게 소월아트홀을 찾아옵니다. 아름다운 선율, 화려한 군무, 깊은 서사가 어우러져 전 세계 관객에게 사랑받는 스터디셀러 공연! 사랑하는 가족과 함께 최고의 크리스마스를 소월아트홀에서 보내세요."
        },
    {
            "공연/행사명": "[서울공예박물관] 금기숙 기증특별전 [Dancing, Dreaming, Enlightening]",
            "이용대상": "누구나",
            "이용요금": "무료",
            "프로그램소개": ""
        },
    {
            "공연/행사명": "[강동문화재단] 쇼뮤지컬 [프린세스 캐치! 티니핑]",
            "이용대상": "24개월 이상 관람가",
            "이용요금": "R석 77,000원 / S석 55,000원",
            "프로그램소개": ""
        }
]

print("샘플 행사 수:", len(events))
print("키 목록:", events[0].keys())


if any(x in events[4]['이용대상'] for x in ['어린이', '가족', '유아', '청소년']):
    print("TRUE")
else : 
    print('FALSE')

if any( '무료' in events[4]['이용요금']):
    print("TRUE")
else : 
    print('FALSE')
# Out:
# 샘플 행사 수: 5
# 키 목록: dict_keys(['공연/행사명', '이용대상', '이용요금', '프로그램소개'])
# FALSE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 43
#      39     print("TRUE")
#      40 else :
#      41     print('FALSE')
#      42
# ---> 43 if any( '무료' in events[4]['이용요금']):
#      44     print("TRUE")
#      45 else :
#      46     print('FALSE')
#
# TypeError: 'bool' object is not iterable
