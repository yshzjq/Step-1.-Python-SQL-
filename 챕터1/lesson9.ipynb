# %%
for x in [1,2,3]:
    print(x)
# Out:
# 1
# 2
# 3

# %%
fruits = ["사과","바나나","포도"]

for fruit in fruits:
    print(fruit)
# Out:
# 사과
# 바나나
# 포도

# %%
age_list = [10,20,30,40,50]

for age in age_list:
    print('내 나이는', str(age),'살이다')
# Out:
# 내 나이는 10 살이다
# 내 나이는 20 살이다
# 내 나이는 30 살이다
# 내 나이는 40 살이다
# 내 나이는 50 살이다

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for ch in 'word':
    print(ch)
# Out:
# w
# o
# r
# d

# %%
events = [
    {
            "공연/행사명": "[동작문화재단] 2025 본동어울마당 아트홀 정기 기획공연 [본?사람?잇다] 7회차",
            "이용대상": "누구나",
            "이용요금": "무료",
            "프로그램소개": "어린이들이 상상력과 창의력을 키울 수 있도록 기획된 융합형 예술 공연을 선보인다. 마술, 샌드아트, 쉐도우쇼, 레이저 퍼포먼스 등 다양한 장르가 어우러져 어린이 관객들에게 공연에 대한 몰입과 감동을 자연스럽게 선사한다."
        },
    {
            "공연/행사명": "[영등포문화재단] 2025 YDP창의예술교육센터 결과공유축제 [둥둥제]",
            "이용대상": "성인, 청소년, 어린이 ",
            "이용요금": "무료 ",
            "프로그램소개": "창터 창작공간 프로그램, 창터 X 공방협력 프로그램, 둥둥 특강 "
        },
    {
            "공연/행사명": "[강북문화재단] 어린이 뮤지컬 [목짧은 기린 지피]",
            "이용대상": "누구나",
            "이용요금": "전석 30,000원",
            "프로그램소개": "7관왕에 빛나는 화제의 웰메이드 어린이 뮤지컬"
        },
    {
            "공연/행사명": "[서울백제어린이박물관] 서울역사생태탐험대4 ",
            "이용대상": "유아~초등2학년 동반 가족, 6~7세 유아 단체",
            "이용요금": "무료",
            "프로그램소개": ""
        },
    {
            "공연/행사명": "괴물도감",
            "이용대상": "만4세 이상 누구나 ",
            "이용요금": "전석 20,000원 / 이벤트할인 10,000원 (어린이, 청소년 한정)",
            "프로그램소개": " 한국문화예술위원회 2025년 어린이 청소년을 위한 예술지원 사업 선정 공연  /  괴물도감 전통 인형극 ‘덜미’를 현대적으로 재해석해, 대중이 쉽고 즐겁게 한국 전통 인형극 "
        }
]

print("샘플 행사 수:", len(events))
# Out:
# 샘플 행사 수: 5

# %% [markdown]
# ’어린이’ 단어가 들어가 있으면 어린이 친화 행사로 보고 필터링해봅시다.

# %%
kid_events = []

for event in events:
    if "어린이" in event['이용대상']:
        kid_events.append(event['공연/행사명'])


print('어린이 대상 행사는', kid_events)
# Out:
# 어린이 대상 행사는 ['[영등포문화재단] 2025 YDP창의예술교육센터 결과공유축제 [둥둥제]']
